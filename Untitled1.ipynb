# %%
# %matplotlib inline

# %%
import pandas as pd

df = pd.read_csv('./data/PastHires.csv')

# %%
df
# Out:
#     Years Experience Employed?  Previous employers Level of Education  \
# 0                 10         Y                   4                 BS
# 1                  0         N                   0                 BS
# 2                  7         N                   6                 BS
# 3                  2         Y                   1                 MS
# 4                 20         N                   2                PhD
# 5                  0         N                   0                PhD
# 6                  5         Y                   2                 MS
# 7                  3         N                   1                 BS
# 8                 15         Y                   5                 BS
# 9                  0         N                   0                 BS
# 10                 1         N                   1                PhD
# 11                 4         Y                   1                 BS
# 12                 0         N                   0                PhD
#
#    Top-tier school Interned Hired
# 0                N        N     Y
# 1                Y        Y     Y
# 2                N        N     N
# 3                Y        N     Y
# 4                Y        N     N
# 5                Y        Y     Y
# 6                N        Y     Y
# 7                N        Y     Y
# 8                N        N     Y
# 9                N        N     N
# 10               Y        N     N
# 11               N        Y     Y
# 12               Y        N     Y

# %%
d = df["Years Experience"].value_counts()

# %%
d.plot(kind="bar")
# Out:
# <Axes: xlabel='Years Experience'>

# %%
count = 1
_ = [count = count+int(i) for i in df[["Years Experience" ]]> 2 if i ]
# Out:
#   Cell In[14], line 2
#     _ = [count = count+int(i) for i in df[["Years Experience" ]]> 2 if i ]
#          ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
count
# Out:
# 1

# %%
count
# Out:
# 1

# %%
import numpy as np
values = np.random.uniform(-10.0, 10.0, 100000)

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(values, 50)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm
x = np.arange(-3,3,0.001)
plt.plot(x, norm.pdf(x, 1.0, 0.5))

# %%
plt.plot(x, norm.pdf(x))

# %%
plt.show()
